# %%
import simpy
import numpy as np

# %%
def gen_interarrival(i):
    inter_arrival=np.random.exponential(1./3.0)
    print("Inter-arrival time for customer {} is {}".format(i,inter_arrival))
    return inter_arrival

# %%
def gen_service(i):
    service_time = np.random.exponential(1./4.0)
    print("The service time for customer {} is {}".format(i,service_time))
    return service_time

# %%
def cafe_run(env,servers):
    i=0
    while True:
        i+=1
        print("Value of i is",i)
        yield env.timeout(gen_interarrival(i))             
        env.process(customer(env,servers,i))
        print(env.active_process)
        print("Checking")

# %%
waiting = []
def customer(env,servers,i):
    t_arrival = env.now
    print("Customer {} has arrived at {}".format(i,env.now) )
    with servers.request() as request:         
        yield request
        print(env.active_process)
        print("Customer {} has started getting service at {}".format(i,env.now))
        yield env.timeout(gen_service(i))
        t_departure = env.now
        print("Customer {} has departed at {}".format(i,env.now))
        waiting.append(t_departure-t_arrival)

# %%
obs_time=[]
queue_length=[]
def observe_process(env,servers):
    while True:
        obs_time.append(env.now)
        queue_length.append(len(servers.queue))
        yield env.timeout(2)

# %%
env=simpy.Environment()
servers = simpy.Resource(env,capacity=1)
env.process(cafe_run(env,servers))
env.process(observe_process(env,servers))
env.run(until=30)
# Out:
# Value of i is 1
# Inter-arrival time for customer 1 is 0.4718683686036163
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 2
# Inter-arrival time for customer 2 is 0.018841747146353158
# Customer 1 has arrived at 0.4718683686036163
# <Process(customer) object at 0x7fd0e45b0940>
# Customer 1 has started getting service at 0.4718683686036163
# The service time for customer 1 is 0.20830647907696156
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 3
# Inter-arrival time for customer 3 is 0.5486545987541294
# Customer 2 has arrived at 0.4907101157499695
# Customer 1 has departed at 0.6801748476805779
# <Process(customer) object at 0x7fd0e45ab700>
# Customer 2 has started getting service at 0.6801748476805779
# The service time for customer 2 is 0.01813757135993659
# Customer 2 has departed at 0.6983124190405144
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 4
# Inter-arrival time for customer 4 is 0.01660887735290717
# Customer 3 has arrived at 1.039364714504099
# <Process(customer) object at 0x7fd0e45b0940>
# Customer 3 has started getting service at 1.039364714504099
# The service time for customer 3 is 0.07757721249569083
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 5
# Inter-arrival time for customer 5 is 0.0174246606626589
# Customer 4 has arrived at 1.0559735918570061
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 6
# Inter-arrival time for customer 6 is 0.2789920743879637
# Customer 5 has arrived at 1.073398252519665
# Customer 3 has departed at 1.1169419269997898
# <Process(customer) object at 0x7fd0e45413d0>
# Customer 4 has started getting service at 1.1169419269997898
# The service time for customer 4 is 0.03877372699922967
# Customer 4 has departed at 1.1557156539990194
# <Process(customer) object at 0x7fd0e4541a00>
# Customer 5 has started getting service at 1.1557156539990194
# The service time for customer 5 is 0.1762368461563
# Customer 5 has departed at 1.3319525001553194
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 7
# Inter-arrival time for customer 7 is 0.17414351416187068
# Customer 6 has arrived at 1.3523903269076287
# <Process(customer) object at 0x7fd0e45417f0>
# Customer 6 has started getting service at 1.3523903269076287
# The service time for customer 6 is 0.5790030020086777
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 8
# Inter-arrival time for customer 8 is 0.8521843074879021
# Customer 7 has arrived at 1.5265338410694995
# Customer 6 has departed at 1.9313933289163066
# <Process(customer) object at 0x7fd0e45410d0>
# Customer 7 has started getting service at 1.9313933289163066
# The service time for customer 7 is 0.07546935134396658
# Customer 7 has departed at 2.006862680260273
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 9
# Inter-arrival time for customer 9 is 0.5225503290641815
# Customer 8 has arrived at 2.3787181485574016
# <Process(customer) object at 0x7fd0e45417f0>
# Customer 8 has started getting service at 2.3787181485574016
# The service time for customer 8 is 0.660821789738696
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 10
# Inter-arrival time for customer 10 is 0.00530437701148819
# Customer 9 has arrived at 2.901268477621583
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 11
# Inter-arrival time for customer 11 is 0.627312588322552
# Customer 10 has arrived at 2.906572854633071
# Customer 8 has departed at 3.0395399382960977
# <Process(customer) object at 0x7fd0e45b85e0>
# Customer 9 has started getting service at 3.0395399382960977
# The service time for customer 9 is 0.0963535310596014
# Customer 9 has departed at 3.135893469355699
# <Process(customer) object at 0x7fd0e45b8880>
# Customer 10 has started getting service at 3.135893469355699
# The service time for customer 10 is 0.026787037125866272
# Customer 10 has departed at 3.162680506481565
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 12
# Inter-arrival time for customer 12 is 0.16634613145030536
# Customer 11 has arrived at 3.533885442955623
# <Process(customer) object at 0x7fd0e45b0f40>
# Customer 11 has started getting service at 3.533885442955623
# The service time for customer 11 is 0.0017548049602649012
# Customer 11 has departed at 3.5356402479158877
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 13
# Inter-arrival time for customer 13 is 0.3779160741038309
# Customer 12 has arrived at 3.700231574405928
# <Process(customer) object at 0x7fd0e45b0f40>
# Customer 12 has started getting service at 3.700231574405928
# The service time for customer 12 is 0.08110730698552417
# Customer 12 has departed at 3.7813388813914526
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 14
# Inter-arrival time for customer 14 is 0.17547942303474368
# Customer 13 has arrived at 4.078147648509759
# <Process(customer) object at 0x7fd0e45b80a0>
# Customer 13 has started getting service at 4.078147648509759
# The service time for customer 13 is 0.07261228124705889
# Customer 13 has departed at 4.150759929756818
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 15
# Inter-arrival time for customer 15 is 0.48481013841672194
# Customer 14 has arrived at 4.253627071544503
# <Process(customer) object at 0x7fd0e45b0f40>
# Customer 14 has started getting service at 4.253627071544503
# The service time for customer 14 is 0.051074630734583806
# Customer 14 has departed at 4.304701702279086
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 16
# Inter-arrival time for customer 16 is 0.11346602450035737
# Customer 15 has arrived at 4.738437209961225
# <Process(customer) object at 0x7fd0e456c7f0>
# Customer 15 has started getting service at 4.738437209961225
# The service time for customer 15 is 0.4020589870691096
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 17
# Inter-arrival time for customer 17 is 0.06196496990248772
# Customer 16 has arrived at 4.851903234461582
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 18
# Inter-arrival time for customer 18 is 0.11417070600627906
# Customer 17 has arrived at 4.91386820436407
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 19
# Inter-arrival time for customer 19 is 0.12942179036524276
# Customer 18 has arrived at 5.0280389103703484
# Customer 15 has departed at 5.140496197030334
# <Process(customer) object at 0x7fd0e454a430>
# Customer 16 has started getting service at 5.140496197030334
# The service time for customer 16 is 0.08387423760750484
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 20
# Inter-arrival time for customer 20 is 0.08109522668683766
# Customer 19 has arrived at 5.157460700735591
# Customer 16 has departed at 5.224370434637839
# <Process(customer) object at 0x7fd0e454aa60>
# Customer 17 has started getting service at 5.224370434637839
# The service time for customer 17 is 0.09424523313169839
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 21
# Inter-arrival time for customer 21 is 0.32606535294814665
# Customer 20 has arrived at 5.2385559274224285
# Customer 17 has departed at 5.318615667769538
# <Process(customer) object at 0x7fd0e454a190>
# Customer 18 has started getting service at 5.318615667769538
# The service time for customer 18 is 0.09024973031490965
# Customer 18 has departed at 5.408865398084448
# <Process(customer) object at 0x7fd0e454a4c0>
# Customer 19 has started getting service at 5.408865398084448
# The service time for customer 19 is 0.06323610855883689
# Customer 19 has departed at 5.472101506643285
# <Process(customer) object at 0x7fd0e4542df0>
# Customer 20 has started getting service at 5.472101506643285
# The service time for customer 20 is 0.05684198463844047
# Customer 20 has departed at 5.5289434912817255
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 22
# Inter-arrival time for customer 22 is 0.10376981717973194
# Customer 21 has arrived at 5.5646212803705755
# <Process(customer) object at 0x7fd0e456cd90>
# Customer 21 has started getting service at 5.5646212803705755
# The service time for customer 21 is 0.3659712641276483
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 23
# Inter-arrival time for customer 23 is 0.1742725682286819
# Customer 22 has arrived at 5.668391097550307
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 24
# Inter-arrival time for customer 24 is 0.05021176819926906
# Customer 23 has arrived at 5.842663665778989
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 25
# Inter-arrival time for customer 25 is 0.01658436585188472
# Customer 24 has arrived at 5.892875433978258
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 26
# Inter-arrival time for customer 26 is 0.30094355086286184
# Customer 25 has arrived at 5.909459799830143
# Customer 21 has departed at 5.930592544498224
# <Process(customer) object at 0x7fd0e456c7c0>
# Customer 22 has started getting service at 5.930592544498224
# The service time for customer 22 is 0.5988904160194896
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 27
# Inter-arrival time for customer 27 is 0.39758073118528525
# Customer 26 has arrived at 6.210403350693005
# Customer 22 has departed at 6.529482960517714
# <Process(customer) object at 0x7fd0e456caf0>
# Customer 23 has started getting service at 6.529482960517714
# The service time for customer 23 is 0.14732096212758805
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 28
# Inter-arrival time for customer 28 is 0.3171289729426873
# Customer 27 has arrived at 6.60798408187829
# Customer 23 has departed at 6.676803922645302
# <Process(customer) object at 0x7fd0e456cc70>
# Customer 24 has started getting service at 6.676803922645302
# The service time for customer 24 is 0.8815946271030279
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 29
# Inter-arrival time for customer 29 is 0.2146783762758168
# Customer 28 has arrived at 6.925113054820978
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 30
# Inter-arrival time for customer 30 is 0.0722064217624699
# Customer 29 has arrived at 7.1397914310967945
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 31
# Inter-arrival time for customer 31 is 0.7621518246395096
# Customer 30 has arrived at 7.211997852859264
# Customer 24 has departed at 7.55839854974833
# <Process(customer) object at 0x7fd0e456c640>
# Customer 25 has started getting service at 7.55839854974833
# The service time for customer 25 is 0.211300449056283
# Customer 25 has departed at 7.769698998804613
# <Process(customer) object at 0x7fd0e454a640>
# Customer 26 has started getting service at 7.769698998804613
# The service time for customer 26 is 0.07703032767236104
# Customer 26 has departed at 7.846729326476974
# <Process(customer) object at 0x7fd0e457d370>
# Customer 27 has started getting service at 7.846729326476974
# The service time for customer 27 is 0.27068050046922043
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 32
# Inter-arrival time for customer 32 is 0.050374131139874025
# Customer 31 has arrived at 7.974149677498774
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 33
# Inter-arrival time for customer 33 is 0.11220086775558716
# Customer 32 has arrived at 8.024523808638648
# Customer 27 has departed at 8.117409826946195
# <Process(customer) object at 0x7fd0e4558160>
# Customer 28 has started getting service at 8.117409826946195
# The service time for customer 28 is 0.1427261183066759
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 34
# Inter-arrival time for customer 34 is 0.08655412421128383
# Customer 33 has arrived at 8.136724676394236
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 35
# Inter-arrival time for customer 35 is 0.45951796083279794
# Customer 34 has arrived at 8.22327880060552
# Customer 28 has departed at 8.260135945252872
# <Process(customer) object at 0x7fd0e45582e0>
# Customer 29 has started getting service at 8.260135945252872
# The service time for customer 29 is 0.11618210682097223
# Customer 29 has departed at 8.376318052073843
# <Process(customer) object at 0x7fd0e4567100>
# Customer 30 has started getting service at 8.376318052073843
# The service time for customer 30 is 0.18284196249264614
# Customer 30 has departed at 8.559160014566489
# <Process(customer) object at 0x7fd0e45b0b50>
# Customer 31 has started getting service at 8.559160014566489
# The service time for customer 31 is 0.19338765379340894
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 36
# Inter-arrival time for customer 36 is 0.10495963987135401
# Customer 35 has arrived at 8.682796761438318
# Customer 31 has departed at 8.752547668359897
# <Process(customer) object at 0x7fd0e45b0be0>
# Customer 32 has started getting service at 8.752547668359897
# The service time for customer 32 is 0.3326991732532812
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 37
# Inter-arrival time for customer 37 is 0.14081968508172737
# Customer 36 has arrived at 8.787756401309672
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 38
# Inter-arrival time for customer 38 is 0.34952981099075486
# Customer 37 has arrived at 8.928576086391399
# Customer 32 has departed at 9.085246841613179
# <Process(customer) object at 0x7fd0e45671c0>
# Customer 33 has started getting service at 9.085246841613179
# The service time for customer 33 is 0.01689016814606316
# Customer 33 has departed at 9.102137009759241
# <Process(customer) object at 0x7fd0e45673d0>
# Customer 34 has started getting service at 9.102137009759241
# The service time for customer 34 is 0.21974102573759152
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 39
# Inter-arrival time for customer 39 is 0.6756503386319446
# Customer 38 has arrived at 9.278105897382153
# Customer 34 has departed at 9.321878035496832
# <Process(customer) object at 0x7fd0e457dcd0>
# Customer 35 has started getting service at 9.321878035496832
# The service time for customer 35 is 0.10975445648161003
# Customer 35 has departed at 9.431632491978442
# <Process(customer) object at 0x7fd0e45582b0>
# Customer 36 has started getting service at 9.431632491978442
# The service time for customer 36 is 0.24074960582012167
# Customer 36 has departed at 9.672382097798565
# <Process(customer) object at 0x7fd0e4558430>
# Customer 37 has started getting service at 9.672382097798565
# The service time for customer 37 is 0.06411234345092723
# Customer 37 has departed at 9.736494441249492
# <Process(customer) object at 0x7fd0e45b09a0>
# Customer 38 has started getting service at 9.736494441249492
# The service time for customer 38 is 0.3024601031323866
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 40
# Inter-arrival time for customer 40 is 0.0577518132187829
# Customer 39 has arrived at 9.953756236014097
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 41
# Inter-arrival time for customer 41 is 0.22770324006245957
# Customer 40 has arrived at 10.01150804923288
# Customer 38 has departed at 10.038954544381879
# <Process(customer) object at 0x7fd0e457de80>
# Customer 39 has started getting service at 10.038954544381879
# The service time for customer 39 is 0.0417813737442759
# Customer 39 has departed at 10.080735918126155
# <Process(customer) object at 0x7fd0e45b0d60>
# Customer 40 has started getting service at 10.080735918126155
# The service time for customer 40 is 0.03342779460680546
# Customer 40 has departed at 10.11416371273296
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 42
# Inter-arrival time for customer 42 is 0.30053608162589396
# Customer 41 has arrived at 10.239211289295339
# <Process(customer) object at 0x7fd0e457de80>
# Customer 41 has started getting service at 10.239211289295339
# The service time for customer 41 is 0.30482002008700093
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 43
# Inter-arrival time for customer 43 is 0.371852589733704
# Customer 42 has arrived at 10.539747370921233
# Customer 41 has departed at 10.54403130938234
# <Process(customer) object at 0x7fd0e457dac0>
# Customer 42 has started getting service at 10.54403130938234
# The service time for customer 42 is 1.0577830908224324
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 44
# Inter-arrival time for customer 44 is 0.13652656117466172
# Customer 43 has arrived at 10.911599960654938
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 45
# Inter-arrival time for customer 45 is 0.5944982339261385
# Customer 44 has arrived at 11.0481265218296
# Customer 42 has departed at 11.601814400204773
# <Process(customer) object at 0x7fd0e4567460>
# Customer 43 has started getting service at 11.601814400204773
# The service time for customer 43 is 0.002371898306518847
# Customer 43 has departed at 11.604186298511292
# <Process(customer) object at 0x7fd0e45676a0>
# Customer 44 has started getting service at 11.604186298511292
# The service time for customer 44 is 0.023859792257603766
# Customer 44 has departed at 11.628046090768896
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 46
# Inter-arrival time for customer 46 is 0.10391303865737696
# Customer 45 has arrived at 11.642624755755739
# <Process(customer) object at 0x7fd0e4567460>
# Customer 45 has started getting service at 11.642624755755739
# The service time for customer 45 is 0.1743692592354426
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 47
# Inter-arrival time for customer 47 is 0.3331423453609459
# Customer 46 has arrived at 11.746537794413115
# Customer 45 has departed at 11.816994014991181
# <Process(customer) object at 0x7fd0e45676a0>
# Customer 46 has started getting service at 11.816994014991181
# The service time for customer 46 is 0.11989353566651538
# Customer 46 has departed at 11.936887550657696
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 48
# Inter-arrival time for customer 48 is 0.11975964978280915
# Customer 47 has arrived at 12.07968013977406
# <Process(customer) object at 0x7fd0e45b0820>
# Customer 47 has started getting service at 12.07968013977406
# The service time for customer 47 is 0.907118460343624
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 49
# Inter-arrival time for customer 49 is 0.2577000941225868
# Customer 48 has arrived at 12.19943978955687
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 50
# Inter-arrival time for customer 50 is 0.5039846026233099
# Customer 49 has arrived at 12.457139883679456
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 51
# Inter-arrival time for customer 51 is 0.48959473122634256
# Customer 50 has arrived at 12.961124486302767
# Customer 47 has departed at 12.986798600117684
# <Process(customer) object at 0x7fd0e45672e0>
# Customer 48 has started getting service at 12.986798600117684
# The service time for customer 48 is 0.018446435210022996
# Customer 48 has departed at 13.005245035327707
# <Process(customer) object at 0x7fd0e45673d0>
# Customer 49 has started getting service at 13.005245035327707
# The service time for customer 49 is 0.13084335685439752
# Customer 49 has departed at 13.136088392182105
# <Process(customer) object at 0x7fd0e4558250>
# Customer 50 has started getting service at 13.136088392182105
# The service time for customer 50 is 0.03366066433869185
# Customer 50 has departed at 13.169749056520796
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 52
# Inter-arrival time for customer 52 is 0.024190488893918824
# Customer 51 has arrived at 13.450719217529109
# <Process(customer) object at 0x7fd0e457dfa0>
# Customer 51 has started getting service at 13.450719217529109
# The service time for customer 51 is 0.26112787230034645
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 53
# Inter-arrival time for customer 53 is 0.11881231220652608
# Customer 52 has arrived at 13.474909706423027
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 54
# Inter-arrival time for customer 54 is 0.1681154595765702
# Customer 53 has arrived at 13.593722018629553
# Customer 51 has departed at 13.711847089829455
# <Process(customer) object at 0x7fd0e4567370>
# Customer 52 has started getting service at 13.711847089829455
# The service time for customer 52 is 0.1646561221994121
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 55
# Inter-arrival time for customer 55 is 0.026128386297180103
# Customer 54 has arrived at 13.761837478206123
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 56
# Inter-arrival time for customer 56 is 0.10854117265026937
# Customer 55 has arrived at 13.787965864503304
# Customer 52 has departed at 13.876503212028867
# <Process(customer) object at 0x7fd0e4567100>
# Customer 53 has started getting service at 13.876503212028867
# The service time for customer 53 is 0.20764878004975498
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 57
# Inter-arrival time for customer 57 is 0.01470843856865649
# Customer 56 has arrived at 13.896507037153574
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 58
# Inter-arrival time for customer 58 is 0.8976129026695436
# Customer 57 has arrived at 13.91121547572223
# Customer 53 has departed at 14.084151992078622
# <Process(customer) object at 0x7fd0e454aa00>
# Customer 54 has started getting service at 14.084151992078622
# The service time for customer 54 is 0.03382218606688526
# Customer 54 has departed at 14.117974178145507
# <Process(customer) object at 0x7fd0e454a8e0>
# Customer 55 has started getting service at 14.117974178145507
# The service time for customer 55 is 0.30889735208140284
# Customer 55 has departed at 14.42687153022691
# <Process(customer) object at 0x7fd0e45ddf70>
# Customer 56 has started getting service at 14.42687153022691
# The service time for customer 56 is 0.04201884547722607
# Customer 56 has departed at 14.468890375704136
# <Process(customer) object at 0x7fd0e45426d0>
# Customer 57 has started getting service at 14.468890375704136
# The service time for customer 57 is 0.5400198112883879
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 59
# Inter-arrival time for customer 59 is 0.6168003148405197
# Customer 58 has arrived at 14.808828378391773
# Customer 57 has departed at 15.008910186992525
# <Process(customer) object at 0x7fd0e454aa30>
# Customer 58 has started getting service at 15.008910186992525
# The service time for customer 58 is 0.23316210609240778
# Customer 58 has departed at 15.242072293084933
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 60
# Inter-arrival time for customer 60 is 0.34015106222198843
# Customer 59 has arrived at 15.425628693232293
# <Process(customer) object at 0x7fd0e454a6a0>
# Customer 59 has started getting service at 15.425628693232293
# The service time for customer 59 is 0.1707039845469301
# Customer 59 has departed at 15.596332677779223
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 61
# Inter-arrival time for customer 61 is 0.8953824458360661
# Customer 60 has arrived at 15.76577975545428
# <Process(customer) object at 0x7fd0e454aac0>
# Customer 60 has started getting service at 15.76577975545428
# The service time for customer 60 is 0.17333923584947886
# Customer 60 has departed at 15.93911899130376
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 62
# Inter-arrival time for customer 62 is 0.2426936496315604
# Customer 61 has arrived at 16.661162201290345
# <Process(customer) object at 0x7fd0e4542e20>
# Customer 61 has started getting service at 16.661162201290345
# The service time for customer 61 is 0.06630845989895238
# Customer 61 has departed at 16.727470661189297
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 63
# Inter-arrival time for customer 63 is 0.48694656977336465
# Customer 62 has arrived at 16.903855850921907
# <Process(customer) object at 0x7fd0e45b0550>
# Customer 62 has started getting service at 16.903855850921907
# The service time for customer 62 is 0.0643710452160273
# Customer 62 has departed at 16.968226896137935
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 64
# Inter-arrival time for customer 64 is 0.34732158604458047
# Customer 63 has arrived at 17.390802420695273
# <Process(customer) object at 0x7fd0e45674c0>
# Customer 63 has started getting service at 17.390802420695273
# The service time for customer 63 is 0.014474791264946716
# Customer 63 has departed at 17.405277211960218
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 65
# Inter-arrival time for customer 65 is 0.040550286847266165
# Customer 64 has arrived at 17.738124006739852
# <Process(customer) object at 0x7fd0e45b0850>
# Customer 64 has started getting service at 17.738124006739852
# The service time for customer 64 is 0.030071261187009368
# Customer 64 has departed at 17.768195267926863
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 66
# Inter-arrival time for customer 66 is 0.23580311619464858
# Customer 65 has arrived at 17.77867429358712
# <Process(customer) object at 0x7fd0e45674c0>
# Customer 65 has started getting service at 17.77867429358712
# The service time for customer 65 is 0.009608647870888587
# Customer 65 has departed at 17.788282941458007
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 67
# Inter-arrival time for customer 67 is 0.01701459009511076
# Customer 66 has arrived at 18.01447740978177
# <Process(customer) object at 0x7fd0e454aac0>
# Customer 66 has started getting service at 18.01447740978177
# The service time for customer 66 is 0.3741188534378131
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 68
# Inter-arrival time for customer 68 is 1.2014539412446699
# Customer 67 has arrived at 18.03149199987688
# Customer 66 has departed at 18.388596263219583
# <Process(customer) object at 0x7fd0e457dcd0>
# Customer 67 has started getting service at 18.388596263219583
# The service time for customer 67 is 0.486827042738658
# Customer 67 has departed at 18.87542330595824
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 69
# Inter-arrival time for customer 69 is 0.298614000407593
# Customer 68 has arrived at 19.23294594112155
# <Process(customer) object at 0x7fd0e454aac0>
# Customer 68 has started getting service at 19.23294594112155
# The service time for customer 68 is 0.002489259981271152
# Customer 68 has departed at 19.23543520110282
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 70
# Inter-arrival time for customer 70 is 0.7819268843432405
# Customer 69 has arrived at 19.531559941529142
# <Process(customer) object at 0x7fd0e457db20>
# Customer 69 has started getting service at 19.531559941529142
# The service time for customer 69 is 0.06562759071883499
# Customer 69 has departed at 19.59718753224798
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 71
# Inter-arrival time for customer 71 is 0.2516022816201785
# Customer 70 has arrived at 20.31348682587238
# <Process(customer) object at 0x7fd0e457de20>
# Customer 70 has started getting service at 20.31348682587238
# The service time for customer 70 is 0.10477894455332931
# Customer 70 has departed at 20.41826577042571
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 72
# Inter-arrival time for customer 72 is 0.9220971892876342
# Customer 71 has arrived at 20.56508910749256
# <Process(customer) object at 0x7fd0e457de20>
# Customer 71 has started getting service at 20.56508910749256
# The service time for customer 71 is 0.260137021713081
# Customer 71 has departed at 20.825226129205642
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 73
# Inter-arrival time for customer 73 is 0.19481426668081372
# Customer 72 has arrived at 21.487186296780195
# <Process(customer) object at 0x7fd0e457dbb0>
# Customer 72 has started getting service at 21.487186296780195
# The service time for customer 72 is 0.5942967277203943
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 74
# Inter-arrival time for customer 74 is 0.055851092816803685
# Customer 73 has arrived at 21.68200056346101
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 75
# Inter-arrival time for customer 75 is 0.8323280452042157
# Customer 74 has arrived at 21.737851656277815
# Customer 72 has departed at 22.08148302450059
# <Process(customer) object at 0x7fd0e4542eb0>
# Customer 73 has started getting service at 22.08148302450059
# The service time for customer 73 is 0.19363781767251306
# Customer 73 has departed at 22.275120842173102
# <Process(customer) object at 0x7fd0e4542ee0>
# Customer 74 has started getting service at 22.275120842173102
# The service time for customer 74 is 0.6204486449968127
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 76
# Inter-arrival time for customer 76 is 0.5936966451092441
# Customer 75 has arrived at 22.57017970148203
# Customer 74 has departed at 22.895569487169915
# <Process(customer) object at 0x7fd0e454a4c0>
# Customer 75 has started getting service at 22.895569487169915
# The service time for customer 75 is 0.12017572515037875
# Customer 75 has departed at 23.015745212320294
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 77
# Inter-arrival time for customer 77 is 1.3291438980607593
# Customer 76 has arrived at 23.163876346591273
# <Process(customer) object at 0x7fd0e454a550>
# Customer 76 has started getting service at 23.163876346591273
# The service time for customer 76 is 0.10149181580987832
# Customer 76 has departed at 23.265368162401153
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 78
# Inter-arrival time for customer 78 is 0.07874943468506322
# Customer 77 has arrived at 24.493020244652033
# <Process(customer) object at 0x7fd0e454a550>
# Customer 77 has started getting service at 24.493020244652033
# The service time for customer 77 is 0.10486230126410502
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 79
# Inter-arrival time for customer 79 is 0.9196976433243143
# Customer 78 has arrived at 24.571769679337095
# Customer 77 has departed at 24.59788254591614
# <Process(customer) object at 0x7fd0e45ddfd0>
# Customer 78 has started getting service at 24.59788254591614
# The service time for customer 78 is 0.16417407854051871
# Customer 78 has departed at 24.76205662445666
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 80
# Inter-arrival time for customer 80 is 0.1320574401047559
# Customer 79 has arrived at 25.49146732266141
# <Process(customer) object at 0x7fd0e4558130>
# Customer 79 has started getting service at 25.49146732266141
# The service time for customer 79 is 0.3020877679232171
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 81
# Inter-arrival time for customer 81 is 0.7096034435895168
# Customer 80 has arrived at 25.623524762766166
# Customer 79 has departed at 25.79355509058463
# <Process(customer) object at 0x7fd0e457df40>
# Customer 80 has started getting service at 25.79355509058463
# The service time for customer 80 is 0.09731806274552494
# Customer 80 has departed at 25.890873153330155
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 82
# Inter-arrival time for customer 82 is 0.576286110029088
# Customer 81 has arrived at 26.333128206355685
# <Process(customer) object at 0x7fd0e454a2b0>
# Customer 81 has started getting service at 26.333128206355685
# The service time for customer 81 is 0.3061583426377146
# Customer 81 has departed at 26.6392865489934
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 83
# Inter-arrival time for customer 83 is 0.6122264658212244
# Customer 82 has arrived at 26.909414316384773
# <Process(customer) object at 0x7fd0e4567250>
# Customer 82 has started getting service at 26.909414316384773
# The service time for customer 82 is 0.08239632739270848
# Customer 82 has departed at 26.99181064377748
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 84
# Inter-arrival time for customer 84 is 0.08879704139916701
# Customer 83 has arrived at 27.521640782205996
# <Process(customer) object at 0x7fd0e456cd00>
# Customer 83 has started getting service at 27.521640782205996
# The service time for customer 83 is 0.41508323339624215
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 85
# Inter-arrival time for customer 85 is 0.172908813934529
# Customer 84 has arrived at 27.610437823605164
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 86
# Inter-arrival time for customer 86 is 0.20581119451537394
# Customer 85 has arrived at 27.783346637539694
# Customer 83 has departed at 27.936724015602238
# <Process(customer) object at 0x7fd0e45b81f0>
# Customer 84 has started getting service at 27.936724015602238
# The service time for customer 84 is 0.013037139956581291
# Customer 84 has departed at 27.949761155558818
# <Process(customer) object at 0x7fd0e45b8d30>
# Customer 85 has started getting service at 27.949761155558818
# The service time for customer 85 is 0.1132564450884945
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 87
# Inter-arrival time for customer 87 is 0.6909557379740674
# Customer 86 has arrived at 27.989157832055067
# Customer 85 has departed at 28.063017600647314
# <Process(customer) object at 0x7fd0e45412e0>
# Customer 86 has started getting service at 28.063017600647314
# The service time for customer 86 is 0.6882629308119393
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 88
# Inter-arrival time for customer 88 is 0.25889529195773925
# Customer 87 has arrived at 28.680113570029135
# Customer 86 has departed at 28.75128053145925
# <Process(customer) object at 0x7fd0e4541970>
# Customer 87 has started getting service at 28.75128053145925
# The service time for customer 87 is 0.1942871919007302
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 89
# Inter-arrival time for customer 89 is 0.06606605033675703
# Customer 88 has arrived at 28.939008861986874
# Customer 87 has departed at 28.945567723359982
# <Process(customer) object at 0x7fd0e4541e20>
# Customer 88 has started getting service at 28.945567723359982
# The service time for customer 88 is 0.7532821381234449
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 90
# Inter-arrival time for customer 90 is 0.2817775331875208
# Customer 89 has arrived at 29.005074912323632
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 91
# Inter-arrival time for customer 91 is 0.09804099635701154
# Customer 90 has arrived at 29.286852445511155
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 92
# Inter-arrival time for customer 92 is 0.35236104500662047
# Customer 91 has arrived at 29.384893441868165
# Customer 88 has departed at 29.698849861483428
# <Process(customer) object at 0x7fd0e45b8910>
# Customer 89 has started getting service at 29.698849861483428
# The service time for customer 89 is 0.1253137370081385
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 93
# Inter-arrival time for customer 93 is 0.01452378763106038
# Customer 92 has arrived at 29.737254486874786
# <Process(cafe_run) object at 0x7fd0e45b07f0>
# Checking
# Value of i is 94
# Inter-arrival time for customer 94 is 0.3024404470057608
# Customer 93 has arrived at 29.751778274505845
# Customer 89 has departed at 29.824163598491566
# <Process(customer) object at 0x7fd0e45b85e0>
# Customer 90 has started getting service at 29.824163598491566
# The service time for customer 90 is 0.013071520786490107
# Customer 90 has departed at 29.837235119278056
# <Process(customer) object at 0x7fd0e45b88b0>
# Customer 91 has started getting service at 29.837235119278056
# The service time for customer 91 is 0.00905388239322207
# Customer 91 has departed at 29.846289001671277
# <Process(customer) object at 0x7fd0e45ab4c0>
# Customer 92 has started getting service at 29.846289001671277
# The service time for customer 92 is 0.34666221264614405

# %%
waiting

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.hist(waiting,10,[0,1])

plt.xlabel("Waiting time in minutes")
plt.ylabel("Number of customers")

# %%
queue_length

# %%
plt.figure()
plt.step(obs_time,queue_length,where='post')

# %%
obs_time
